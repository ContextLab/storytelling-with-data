# %%
import hypertools as hyp
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
fname = 'HR_comma_sep.csv'
data = pd.read_csv(fname)

# %%
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
hyp.plot(data, 'k.', model='SpectralEmbedding');

# %%
hyp.plot(data, '.', model='SpectralEmbedding', group=data['salary'])
# Out:
# (<matplotlib.figure.Figure at 0x7f5c97ae1978>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x7f5c7ea86ac8>,
#  [array([[ 0.38,  0.53,  2.  , ...,  0.  ,  1.  ,  0.  ],
#          [ 0.8 ,  0.86,  5.  , ...,  0.  ,  0.  ,  1.  ],
#          [ 0.11,  0.88,  7.  , ...,  0.  ,  0.  ,  1.  ],
#          ...,
#          [ 0.37,  0.53,  2.  , ...,  0.  ,  1.  ,  0.  ],
#          [ 0.11,  0.96,  6.  , ...,  0.  ,  1.  ,  0.  ],
#          [ 0.37,  0.52,  2.  , ...,  0.  ,  1.  ,  0.  ]])],
#  None)

# %%
sns.factorplot(kind='bar', data=data, x='satisfaction_level', y='salary')

# %% [markdown]
# other plot styles: https://seaborn.pydata.org/generated/seaborn.factorplot.html

# %%
sns.factorplot(kind='point', data=data, x='satisfaction_level', y='sales')

# %%
sns.factorplot(kind='bar', data=data, x='number_project', y='sales')

# %%
print('The features of this dataset are %s' % data.columns.values)
# Out:
# The features of this dataset are ['satisfaction_level' 'last_evaluation' 'number_project'
#  'average_montly_hours' 'time_spend_company' 'Work_accident' 'left'
#  'promotion_last_5years' 'sales' 'salary']

# %%
sns.factorplot(kind='bar', data=data, x='last_evaluation', y='sales')

# %%
data['sales']
# Out:
# 0             sales
# 1             sales
# 2             sales
# 3             sales
# 4             sales
# 5             sales
# 6             sales
# 7             sales
# 8             sales
# 9             sales
# 10            sales
# 11            sales
# 12            sales
# 13            sales
# 14            sales
# 15            sales
# 16            sales
# 17            sales
# 18            sales
# 19            sales
# 20            sales
# 21            sales
# 22            sales
# 23            sales
# 24            sales
# 25            sales
# 26            sales
# 27            sales
# 28       accounting
# 29       accounting
#             ...
# 14969         sales
# 14970         sales
# 14971         sales
# 14972    accounting
# 14973    accounting
# 14974    accounting
# 14975            hr
# 14976            hr
# 14977            hr
# 14978            hr
# 14979     technical
# 14980     technical
# 14981     technical
# 14982     technical
# 14983     technical
# 14984     technical
# 14985     technical
# 14986     technical
# 14987     technical
# 14988     technical
# 14989     technical
# 14990       support
# 14991       support
# 14992       support
# 14993       support
# 14994       support
# 14995       support
# 14996       support
# 14997       support
# 14998       support
# Name: sales, Length: 14999, dtype: object

# %%
sns.factorplot(kind='point', data=data, x='satisfaction_level', y='salary')

# %%
sns.factorplot(kind='bar', data=data, x='average_montly_hours', y='sales')

# %%
sns.factorplot(kind='bar', data=data, x='time_spend_company', y='satisfaction_level')

# %% [markdown]
# sns.factorplot(kind='bar', data=data, x='time_spend_company', y='sales')

# %%
sns.factorplot(kind='bar', data=data, x='time_spend_company', y='sales')

# %%
sns.factorplot(kind='bar', data=data, x='left', y='sales')

# %%
hyp.plot(data, '.', group=data['salary'], legend=['low','medium','high'], model='SpectralEmbedding')
# Out:
# (<matplotlib.figure.Figure at 0x7f5c7e3554e0>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x7f5c7decf048>,
#  [array([[ 0.38,  0.53,  2.  , ...,  0.  ,  1.  ,  0.  ],
#          [ 0.8 ,  0.86,  5.  , ...,  0.  ,  0.  ,  1.  ],
#          [ 0.11,  0.88,  7.  , ...,  0.  ,  0.  ,  1.  ],
#          ...,
#          [ 0.37,  0.53,  2.  , ...,  0.  ,  1.  ,  0.  ],
#          [ 0.11,  0.96,  6.  , ...,  0.  ,  1.  ,  0.  ],
#          [ 0.37,  0.52,  2.  , ...,  0.  ,  1.  ,  0.  ]])],
#  None)

# %%
data['performance'] = data['salary'].replace({'low': 0, 'medium': 1, 'high': 2})
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary  performance
# 0     low            0
# 1  medium            1
# 2  medium            1
# 3     low            0
# 4     low            0

# %%
sns.factorplot(kind='bar', data=data, x='performance', y='sales')

#performance = salary

# %%
sns.factorplot(kind='bar', data=data, x='salary', y='average_montly_hours')

# %%
sns.factorplot(kind='bar', data=data, x='left', y='average_montly_hours')

# %%
sns.factorplot(kind='bar', data=data, x='promotion_last_5years', y='sales')

# %%
sns.factorplot(kind='bar', data=data, x='promotion_last_5years', y='average_montly_hours')

# %%
sns.factorplot(kind='bar', data=data, x='left', y='average_montly_hours')

# %%
sns.factorplot(kind='bar', data=data, x='number_project', y='average_montly_hours')

# %%
sns.factorplot(kind='bar', data=data, x='average_montly_hours', y='sales')

# %%
sns.factorplot(kind='bar', data=data, x='time_spend_company', y='sales')

# %%
sns.factorplot(kind='bar', data=data, x='left', y='satisfaction_level')
