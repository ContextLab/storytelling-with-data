# %%
import hypertools as hyp
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
fname = 'HR_comma_sep.csv'
data = pd.read_csv(fname)

# %%
data.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
hyp.plot(data, 'k.', model='SpectralEmbedding');

# %%
hyp.plot(data, '.', model='SpectralEmbedding', group=data['salary'])
# Out:
# (<matplotlib.figure.Figure at 0x7f86b1057240>,
#  <matplotlib.axes._subplots.Axes3DSubplot at 0x7f86b0fa99e8>,
#  [array([[ 0.38,  0.53,  2.  , ...,  0.  ,  1.  ,  0.  ],
#          [ 0.8 ,  0.86,  5.  , ...,  0.  ,  0.  ,  1.  ],
#          [ 0.11,  0.88,  7.  , ...,  0.  ,  0.  ,  1.  ],
#          ...,
#          [ 0.37,  0.53,  2.  , ...,  0.  ,  1.  ,  0.  ],
#          [ 0.11,  0.96,  6.  , ...,  0.  ,  1.  ,  0.  ],
#          [ 0.37,  0.52,  2.  , ...,  0.  ,  1.  ,  0.  ]])],
#  None)

# %%
sns.factorplot(kind='bar', data=data, x='satisfaction_level', y='salary')

# %% [markdown]
# other plot styles: https://seaborn.pydata.org/generated/seaborn.factorplot.html
