# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### read in data

# %%
menu = pd.read_csv('menu.csv', index_col=['Category','Item'])

# %% [markdown]
# ### remove units from serving size column, covert type

# %%
menu['Serving Size'] = menu['Serving Size'].apply(lambda x: float(x.split()[0]))
menu.rename({'Serving Size' : 'Serving Size (oz/fl oz)'}, axis='columns', inplace=True)

# %%
menu
# Out:
#                                                                       Serving Size (oz/fl oz)  \
# Category           Item
# Breakfast          Egg McMuffin                                                           4.8
#                    Egg White Delight                                                      4.8
#                    Sausage McMuffin                                                       3.9
#                    Sausage McMuffin with Egg                                              5.7
#                    Sausage McMuffin with Egg Whites                                       5.7
#                    Steak & Egg McMuffin                                                   6.5
#                    Bacon, Egg & Cheese Biscuit (Regular Biscuit)                          5.3
#                    Bacon, Egg & Cheese Biscuit (Large Biscuit)                            5.8
#                    Bacon, Egg & Cheese Biscuit with Egg Whites (Re...                     5.4
# ...
