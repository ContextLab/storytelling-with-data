# %% [markdown]
# <a href="https://colab.research.google.com/github/karimkhalil-byte/storytelling-with-data/blob/master/data-stories/Data-science-jobs/datajobs1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup
#
# This demonstration notebook provides a suggested set of libraries that you might find useful in crafting your data stories.  You should comment out or delete libraries that you don't use in your analysis.

# %%
#number crunching
import numpy as np
from plotly import express as px
import pandas as pd

# %% [markdown]
# # Project team
#
# List your team members and (as appropriate) each team member's role on this project.
#
# # Background and overview
#
# Introduce your question and motivation here.  Link to other resources or related work as appropriate.
#
# # Approach
#
# Briefly describe (at a high level) the approach you'll be taking to answer or explore your question in this notebook.
#
# # Quick summary
#
# Briefly describe your key findings at a high level.

# %% [markdown]
# # Data
#
# Briefly describe your dataset(s), including links to original sources.  Provide any relevant background information specific to your data sources.

# %%
# Provide code for downloading or importing your data here
url = "https://github.com/karimkhalil-byte/storytelling-with-data/raw/master/data-stories/Data-science-jobs/data_cleaned_2021.csv"
df = pd.read_csv(url).drop(labels=['Job Description','Salary Estimate','Company Name','Industry','Competitors','Hourly','Employer provided','Location','Python', 'spark', 'aws', 'excel', 'sql', 'sas', 'keras', 'pytorch',
       'scikit', 'tensor', 'hadoop', 'tableau', 'bi', 'flink', 'mongo','google_an', 'job_title_sim', 'seniority_by_title', 'Degree','Headquarters'], axis=1).rename({'company_txt': 'Company Name'}, axis=1).set_index('index')

# %%
df1 = df.query('`Job Title` == "Data Scientist"')
df2 = df1[df1.Founded != -1]
df2
# Out:
#             Job Title  Rating          Size  Founded  Type of ownership  \
# index
# 0      Data Scientist     3.8   501 - 1000      1973  Company - Private
# 2      Data Scientist     4.8   501 - 1000      2010  Company - Private
# 3      Data Scientist     3.8  1001 - 5000      1965         Government
# 4      Data Scientist     2.9     51 - 200      1998  Company - Private
# 5      Data Scientist     3.4    201 - 500      2000   Company - Public
# ...               ...     ...           ...      ...                ...
# 867    Data Scientist     3.4    201 - 500      2011  Company - Private
# 868    Data Scientist     4.0   501 - 1000      2007  Company - Private
# 878    Data Scientist     3.5    201 - 500      2005   Company - Public
# 879    Data Scientist     4.3    201 - 500      1969  Company - Private
# 880    Data Scientist     2.6       10000+      1997  Company - Private
#
#                              Sector                           Revenue  \
# index
# ...

# %%
# ?px.bar

# %%
df3 = df2.groupby("Founded").mean()
fig = px.bar(df3.reset_index(),x='Founded', y="Avg Salary(K)", )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
job_by_sector =  df2.groupby('Sector').mean()
job_by_revenue =  df2.groupby('Revenue').mean()
job_by_too =  df2.groupby('Type of ownership').mean()
job_by_size =  df2.groupby('Size').mean()

# %%
job_by_sector1 = job_by_sector.sort_values('Avg Salary(K)', ascending=True)

# %%
fig = px.bar(job_by_sector1.reset_index(), x= "Sector", y="Avg Salary(K)", color = "Rating")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#fix x-axis, sort by x-axis
categories = ['Unknown / Non-Applicable',
              '$1 to $5 million (USD)',
              '$10 to $25 million (USD)',
              '$25 to $50 million (USD)', 
              '$50 to $100 million (USD)',
              '$100 to $500 million (USD)', 
              '$500 million to $1 billion (USD)',
              '$1 to $2 billion (USD)',
              '$2 to $5 billion (USD)',
              '$5 to $10 billion (USD)',              
              '$10+ billion (USD)']

job_by_revenue1 = job_by_revenue.copy().sort_values('Avg Salary(K)', ascending=True)
job_by_revenue1 = job_by_revenue1.rename({c: c.replace('$', '') for c in categories}, axis=0).reset_index()

fig = px.bar(job_by_revenue1, x = "Revenue", y="Avg Salary(K)", color = "Rating", 
             category_orders={'Revenue': [c.replace('$', '') for c in categories]})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
job_by_revenue1
# Out:
#                              Revenue    Rating      Founded  Lower Salary  \
# 0            50 to 100 million (USD)  4.175000  1958.750000     59.750000
# 1              5 to 10 billion (USD)  3.766667  1966.666667     66.666667
# 2             25 to 50 million (USD)  3.985714  2006.714286     69.428571
# 3             10 to 25 million (USD)  4.112500  1986.875000     73.500000
# 4               1 to 2 billion (USD)  3.460000  1958.466667     75.333333
# 5   $500 million to $1 billion (USD)  3.730000  1929.800000     74.500000
# 6               2 to 5 billion (USD)  3.525000  1973.750000     79.750000
# 7           100 to 500 million (USD)  4.044444  1995.000000     82.777778
# 8           Unknown / Non-Applicable  3.837838  2003.945946     84.297297
# 9                  10+ billion (USD)  3.680000  1891.800000     86.100000
# 10              1 to 5 million (USD)  3.350000  2011.000000     91.000000
#
#     Upper Salary  Avg Salary(K)         Age
# ...

# %%
job_by_revenue1
# Out:
#                                     Rating      Founded  Lower Salary  \
# Revenue
# 50 to 100 million (USD)           4.175000  1958.750000     59.750000
# 5 to 10 billion (USD)             3.766667  1966.666667     66.666667
# 25 to 50 million (USD)            3.985714  2006.714286     69.428571
# 10 to 25 million (USD)            4.112500  1986.875000     73.500000
# 1 to 2 billion (USD)              3.460000  1958.466667     75.333333
# $500 million to $1 billion (USD)  3.730000  1929.800000     74.500000
# 2 to 5 billion (USD)              3.525000  1973.750000     79.750000
# 100 to 500 million (USD)          4.044444  1995.000000     82.777778
# Unknown / Non-Applicable          3.837838  2003.945946     84.297297
# 10+ billion (USD)                 3.680000  1891.800000     86.100000
# 1 to 5 million (USD)              3.350000  2011.000000     91.000000
#
#                                   Upper Salary  Avg Salary(K)         Age
# Revenue
# ...

# %%
#fix x-axis, sort by x-axis

job_by_size1 = job_by_size.sort_values('Avg Salary(K)', ascending=True)
fig = px.bar(job_by_size1.reset_index(), x= "Size", y="Avg Salary(K)",
             color = "Rating",
             category_orders={'Size': ['1 - 50 ', '51 - 200 ', '201 - 500 ',
                                       '501 - 1000 ', '1001 - 5000 ',
                                       '5001 - 10000 ', '10000+ ']})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#fix x-axis too
job_by_too1 = job_by_too.sort_values('Avg Salary(K)', ascending=True)
fig = px.bar(job_by_too1.reset_index(), x= "Type of ownership", y="Avg Salary(K)",color = "Rating")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df2 = df2.groupby('Job Location').mean().reset_index()

# %%
px.choropleth(data_frame=df2, color='Avg Salary(K)', locations='Job Location', locationmode='USA-states', scope='usa',color_continuous_scale='bupu')

# %%
px.choropleth(data_frame=df2, color='Rating', locations='Job Location', locationmode='USA-states', scope='usa', range_color = (0,5), color_continuous_scale='bupu')

# %%
df2

df2_cor = df2.copy()
pos_dictionary = {'1 - 50 ': 1, '51 - 200 ' : 2, '201 - 500 ':3,'501 - 1000 ':4,'1001 - 5000 ':5, '5001 - 10000 ' :6, '10000+ ':7 }
df2_cor['Size'] = df2_cor['Size'].apply(lambda x: pos_dictionary[x])
df2_cor
# Out:
#             Job Title  Rating  Size  Founded  Type of ownership  \
# index
# 0      Data Scientist     3.8     4     1973  Company - Private
# 2      Data Scientist     4.8     4     2010  Company - Private
# 3      Data Scientist     3.8     5     1965         Government
# 4      Data Scientist     2.9     2     1998  Company - Private
# 5      Data Scientist     3.4     3     2000   Company - Public
# ...               ...     ...   ...      ...                ...
# 867    Data Scientist     3.4     3     2011  Company - Private
# 868    Data Scientist     4.0     4     2007  Company - Private
# 878    Data Scientist     3.5     3     2005   Company - Public
# 879    Data Scientist     4.3     3     1969  Company - Private
# 880    Data Scientist     2.6     7     1997  Company - Private
#
#                              Sector                           Revenue  \
# index
# 0               Aerospace & Defense         $50 to $100 million (USD)
# ...

# %%
column_1 = df2_cor["Size"]
column_2 = df2_cor["Age"]
correlation = column_1.corr(column_2)
print(correlation)
# Out:
# 0.5027734883595709

# %%
px.scatter(data_frame=df2_cor, x='Age', y='Size', trendline = 'ols', trendline_color_override='red')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
pos_dictionary1 = {'Unknown / Non-Applicable':0,
              '$1 to $5 million (USD)':1,
              '$10 to $25 million (USD)':2,
              '$25 to $50 million (USD)':3, 
              '$50 to $100 million (USD)':4,
              '$100 to $500 million (USD)':5, 
              '$500 million to $1 billion (USD)':6,
              '$1 to $2 billion (USD)':7,
              '$2 to $5 billion (USD)':8,
              '$5 to $10 billion (USD)':9,              
              '$10+ billion (USD)':10}

df2_cor['Revenue'] = df2_cor['Revenue'].apply(lambda x: pos_dictionary1[x])
df2_cor
# Out:
#             Job Title  Rating  Size  Founded  Type of ownership  \
# index
# 0      Data Scientist     3.8     4     1973  Company - Private
# 2      Data Scientist     4.8     4     2010  Company - Private
# 3      Data Scientist     3.8     5     1965         Government
# 4      Data Scientist     2.9     2     1998  Company - Private
# 5      Data Scientist     3.4     3     2000   Company - Public
# ...               ...     ...   ...      ...                ...
# 867    Data Scientist     3.4     3     2011  Company - Private
# 868    Data Scientist     4.0     4     2007  Company - Private
# 878    Data Scientist     3.5     3     2005   Company - Public
# 879    Data Scientist     4.3     3     1969  Company - Private
# 880    Data Scientist     2.6     7     1997  Company - Private
#
#                              Sector  Revenue  Lower Salary  Upper Salary  \
# index
# 0               Aerospace & Defense        4            53            91
# ...

# %%
column_1 = df2_cor["Revenue"]
column_2 = df2_cor["Age"]
correlation = column_1.corr(column_2)
print(correlation)
# Out:
# 0.5248934261379262

# %%
px.scatter(data_frame=df2_cor, x='Age', y='Revenue', trendline = 'ols', trendline_color_override='red')
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Analysis
#
# Briefly describe each step of your analysis, followed by the code implementing that part of the analysis and/or producing the relevant figures.  (Copy this text block and the following code block as many times as are needed.)

# %%
# Provide code for carrying out the part of your analysis described
# in the previous text block.  Any statistics or figures should be displayed
# in the notebook.

# %% [markdown]
# # Interpretations and conclusions
#
# Describe and discuss your findings and say how they answer your question (or how they failed to answer your question).  Also describe the current state of your project-- e.g., is this a "complete" story, or is further exploration needed?
#
# # Future directions
#
# Describe some open questions or tasks that another interested individual or group might be able to pick up from, using your work as a starting point.
