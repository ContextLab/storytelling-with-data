# %%
import pandas as pd
import numpy as np
import seaborn as sns
#sns.set_context('poster')
# %matplotlib inline

# %%
import os

# %%
os.getcwd()
# Out:
# '/mnt/storytelling-with-data/data-stories/happiness'

# %%
# Read data:

#data = pd.read_csv('GSS 4.csv', sheetname = 'Data')
#data.head(5)

# %%
data = pd.read_csv ('GSS 4.csv')
data.head()
# Out:
#    Unnamed: 0   age       region     health general_happy   past_week_happy  \
# 0           0  47.0  New england       Good  Pretty happy               NaN
# 1           1  61.0  New england        NaN  Pretty happy               NaN
# 2           2  72.0  New england       Good    Very happy  Most of the time
# 3           3  43.0  New england       Good  Pretty happy               NaN
# 4           4  55.0  New england  Excellent    Very happy  Most of the time
#
#         see_friends     see_relatives    income  work_hours job_satisfaction  \
# 0  Sev times a year      Almost daily  170000.0         NaN   Mod. satisfied
# 1  Sev times a year  Sev times a year   54999.0         NaN   Very satisfied
# 2               NaN               NaN       NaN         NaN              NaN
# 3  Sev times a week  Sev times a week   11249.0         NaN   Very satisfied
# 4               NaN               NaN    1999.0         NaN   Mod. satisfied
#
# ...

# %%
# Clean data:

data = data.replace('Not applicable', np.NaN)
data.head(5)
# Out:
#    Unnamed: 0   age       region     health general_happy   past_week_happy  \
# 0           0  47.0  New england       Good  Pretty happy               NaN
# 1           1  61.0  New england        NaN  Pretty happy               NaN
# 2           2  72.0  New england       Good    Very happy  Most of the time
# 3           3  43.0  New england       Good  Pretty happy               NaN
# 4           4  55.0  New england  Excellent    Very happy  Most of the time
#
#         see_friends     see_relatives    income  work_hours job_satisfaction  \
# 0  Sev times a year      Almost daily  170000.0         NaN   Mod. satisfied
# 1  Sev times a year  Sev times a year   54999.0         NaN   Very satisfied
# 2               NaN               NaN       NaN         NaN              NaN
# 3  Sev times a week  Sev times a week   11249.0         NaN   Very satisfied
# 4               NaN               NaN    1999.0         NaN   Mod. satisfied
#
# ...

# %%
sns.set_palette('muted')
sns.set_style('ticks')

for col in data.columns.values:
    sns.countplot(data=data, x=col)
    sns.plt.show()

# %%
sns.barplot(data=data, x='weekday_internet', y ='general_happy' , order =['Very happy' , 'Pretty happy' , 'Not too happy'])
sns.plt.title('Does internet use affect general happiness?')
sns.plt.show()

# %%
sns.swarmplot(data=data, x='weekday_internet', y ='general_happy' , order =['Very happy' , 'Pretty happy' , 'Not too happy'])
sns.plt.title('Does internet use affect general happiness?')
sns.plt.show()

#swarm plot shows highest intern use = most happy... maybe these users falsely identified their happiness level??

# %%
# list the variables you want to correlate
variables_of_interest = ['weekday_internet', 'job_satisfaction', 'use_twitter', 'see_friends', 'income']

# create a correlation matrix
corrmat = data.loc[:,variables_of_interest].corr()

sns.heatmap(corrmat)
sns.plt.show()

features = data.columns.values[:-2]
datamat, labels = hyp.tools.df2mat(data[features], return_labels=True)
datamat = hyp.tools.normalize(datamat)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-8efaa53686a7> in <module>()
#       9
#      10 features = data.columns.values[:-2]
# ---> 11 datamat, labels = hyp.tools.df2mat(data[features], return_labels=True)
#      12 datamat = hyp.tools.normalize(datamat)
#
# NameError: name 'hyp' is not defined

# %%
sns.swarmplot(data=data, x='weekday_internet', y='age')
sns.plt.title('Does birth year affect internet use?')
sns.plt.show()

# %%
sns.regplot(data=data, x='weekday_internet', y='age')
sns.plt.title('Does birth year affect internet use?')
sns.plt.show()

# %%
sns.swarmplot(data=data, x='work_hours', y ='general_happy' , order =['Very happy' , 'Pretty happy' , 'Not too happy'])
sns.plt.title('Does work hours affect happiness?')
sns.plt.show()

# %%
sns.swarmplot(data=data, x='age', y ='general_happy' , order =['Very happy' , 'Pretty happy' , 'Not too happy'])
sns.plt.title('Are birth year & general happiness correlated?')
sns.plt.show()

# %%
data['general_happy'].replace({'not too happy': 1, 'pretty happy': 2, 'very happy': 3})
data.head()})
data.head()
# Out:
#   File "<ipython-input-79-c34040917831>", line 2
#     data.head()})
#                ^
# SyntaxError: invalid syntax

# %%
sns.swarmplot(data=data, x='job_satisfaction', y ='weekday_internet' , order =['A little disatisfied', 'Mod. satisfied', 'Very satisfied'])
sns.plt.title('Does internet use affect general happiness?')
sns.plt.show()

# %%
sns.swarmplot(data=data, x='job_satisfaction', y ='weekend_internet' , order =['A little disatisfied', 'Mod. satisfied', 'Very satisfied'])
sns.plt.title('Does internet use affect general happiness?')
sns.plt.show()

# %%
# list the variables you want to correlate
variables_of_interest = ['weekday_internet', 'weekend_internet', 'internet_per_week', 'work_hours','age', 'income']

# create a correlation matrix
corrmat = data.loc[:,variables_of_interest].corr()

sns.heatmap(corrmat)
sns.plt.show()

# %%
#7 categories total for see_friends
sns.swarmplot(data=data, x='internet_per_week', y ='see_friends' , order =['Never', 'Once a year', 'Sev times a year', 'Once a month', 'Sev time a mnth', 'Sev times a week', 'Almost daily'])                                                                  
sns.plt.title('Are internet use & time spent with friends correlated?')
sns.plt.show()

# %%
#7 categories total for see_relatives
sns.swarmplot(data=data, x='internet_per_week', y ='see_relatives' , order =['Never', 'Once a year', 'Sev times a year', 'Once a month', 'Sev time a mnth', 'Sev times a week', 'Almost daily'])                                                                  
sns.plt.title('Are internet use & time spent with family/relatives correlated?')
sns.plt.show()

# %%
sns.barplot(data=data, x='internet_per_week', y ='see_friends' , order =['Never', 'Once a year', 'Sev times a year', 'Once a month', 'Sev time a mnth', 'Sev times a week', 'Almost daily'])                                                                  
sns.plt.title('Are internet use & time spent with friends correlated?')
sns.plt.show()

# %%
#7 categories total for see_relatives
sns.barplot(data=data, x='internet_per_week', y ='see_relatives' , order =['Never', 'Once a year', 'Sev times a year', 'Once a month', 'Sev time a mnth', 'Sev times a week', 'Almost daily'])                                                                  
sns.plt.title('Are internet use & time spent with family/relatives correlated?')
sns.plt.show()

# %%
g = sns.lmplot(x="internet_per_week", y="work_hours", hue="use_twitter", data=data)
sns.plt.show()

# %%
g = sns.lmplot(x="weekday_internet", y="weekend_internet", hue="use_twitter", data=data)
sns.plt.show()

# %%
sns.swarmplot(data=data, x='internet_per_week', y ='region' , order =['New england', 'Middle atlantic', 'Pacific', 'E. nor. central', 'W. nor. central', 'South atlantic', 'E. sou. central', 'W. sou. central', 'Mountain'])                                                                  
sns.plt.title('Are internet use & regions correlated?')
sns.plt.show()

# %%
sns.barplot(data=data, x='internet_per_week', y ='region' , order =['New england', 'Middle atlantic', 'Pacific', 'E. nor. central', 'W. nor. central', 'South atlantic', 'E. sou. central', 'W. sou. central', 'Mountain'])                                                                  
sns.plt.title('Are internet use & regions correlated?')
sns.plt.show()

# %%
sns.swarmplot(data=data, x='weekday_internet', y ='region' , order =['New england', 'Middle atlantic', 'Pacific', 'E. nor. central', 'W. nor. central', 'South atlantic', 'E. sou. central', 'W. sou. central', 'Mountain'])                                                                  
sns.plt.title('Is weekday internet use & regions correlated?')
sns.plt.show()

# %%
sns.swarmplot(data=data, x='weekend_internet', y ='region' , order =['New england', 'Middle atlantic', 'Pacific', 'E. nor. central', 'W. nor. central', 'South atlantic', 'E. sou. central', 'W. sou. central', 'Mountain'])                                                                  
sns.plt.title('Is weekend internet use & regions correlated?')
sns.plt.show()

# %%
sns.barplot(data=data, x='weekday_internet', y ='region' , order =['New england', 'Middle atlantic', 'Pacific', 'E. nor. central', 'W. nor. central', 'South atlantic', 'E. sou. central', 'W. sou. central', 'Mountain'])                                                                  
sns.plt.title('Is weekday internet use & regions correlated?')
sns.plt.show()

sns.barplot(data=data, x='weekend_internet', y ='region' , order =['New england', 'Middle atlantic', 'Pacific', 'E. nor. central', 'W. nor. central', 'South atlantic', 'E. sou. central', 'W. sou. central', 'Mountain'])                                                                  
sns.plt.title('Is weekend internet use & regions correlated?')
sns.plt.show()

# %%
sns.swarmplot(data=data, x='weekend_internet', y ='weekday_internet')                                                                  
sns.plt.title('Is weekend & weekday internet uses correlated?')
sns.plt.show()

sns.barplot(data=data, x='weekend_internet', y ='weekday_internet')                                                                  
sns.plt.title('Is weekend & weekday internet uses correlated?')
sns.plt.show()

# %%
g = sns.lmplot(x="weekday_internet", y="weekend_internet", hue="region", data=data)
sns.plt.show()

g = sns.lmplot(data=data, x= "internet_per_week", y= "income", hue = "region")
sns.plt.show()

g = sns.lmplot(data=data, x= "internet_per_week", y= "income", hue = "general_happy")
sns.plt.show()

# %%
sns.swarmplot(data=data, x='internet_per_week', y ='general_happy' , order =['Very happy' , 'Pretty happy' , 'Not too happy'])
sns.plt.title('Does internet use affect happiness?')
sns.plt.show()

sns.barplot(data=data, x='internet_per_week', y ='general_happy' , order =['Very happy' , 'Pretty happy' , 'Not too happy'])
sns.plt.title('Does internet use affect happiness?')
sns.plt.show()

sns.swarmplot(data=data, x='weekday_internet', y ='general_happy' , order =['Very happy' , 'Pretty happy' , 'Not too happy'])
sns.plt.title('Does internet use affect happiness?')
sns.plt.show()

sns.barplot(data=data, x='weekday_internet', y ='general_happy' , order =['Very happy' , 'Pretty happy' , 'Not too happy'])
sns.plt.title('Does internet use affect happiness?')
sns.plt.show()

sns.barplot(data=data, x='weekend_internet', y ='general_happy' , order =['Very happy' , 'Pretty happy' , 'Not too happy'])
sns.plt.title('Does internet use affect happiness?')
sns.plt.show()

# %%
#more variation in weekend_internet & happiness -> hypothesis: more consistency in weekday_internet bc jobs but variation in weekend_internet is more indicative of happiness

# %%
sns.swarmplot(data=data, x='internet_per_week', y ='income')                                                                  
sns.plt.title('Is internet use & income correlated?')
sns.plt.show()

sns.barplot(data=data, x='internet_per_week', y ='income')                                                                  
sns.plt.title('Is weekend & weekday internet uses correlated?')
sns.plt.show()

# %%
sns.swarmplot(data=data, x='internet_per_week', y ='region' , order =['New england', 'Middle atlantic', 'Pacific', 'E. nor. central', 'W. nor. central', 'South atlantic', 'E. sou. central', 'W. sou. central', 'Mountain'])                                                                  
sns.plt.title('Ist internet use & regions correlated?')
sns.plt.show()

# %%
sns.swarmplot(data=data, y='income', x ='region' , order =['New england', 'Middle atlantic', 'Pacific', 'E. nor. central', 'W. nor. central', 'South atlantic', 'E. sou. central', 'W. sou. central', 'Mountain'])                                                                  
sns.plt.title('Are income & regions correlated?')
sns.plt.show()

sns.barplot(data=data, y='income', x ='region' , order =['New england', 'Middle atlantic', 'Pacific', 'E. nor. central', 'W. nor. central', 'South atlantic', 'E. sou. central', 'W. sou. central', 'Mountain'])                                                                  
sns.plt.title('Are income & regions correlated?')
sns.plt.show()

# %%
g = sns.lmplot(x="weekday_internet", y="weekend_internet", hue="region", data=data)
sns.plt.show()

g = sns.lmplot(data=data, x= "internet_per_week", y= "income", hue = "region")
sns.plt.show()

g = sns.lmplot(data=data, x= "internet_per_week", y= "income", hue = "general_happy")
sns.plt.show()

# %%
sns.swarmplot(data=data, x='income', y ='general_happy' , order =['Very happy' , 'Pretty happy' , 'Not too happy'])
sns.plt.title('Does income affect happiness?')
sns.plt.show()

sns.barplot(data=data, x='income', y ='general_happy' , order =['Very happy' , 'Pretty happy' , 'Not too happy'])
sns.plt.title('Does income use affect happiness?')
sns.plt.show()

# %%
sns.violinplot(data=data, x='income', y ='general_happy' , order =['Very happy' , 'Pretty happy' , 'Not too happy'])
sns.plt.title('Does income use affect happiness?')
sns.plt.show()

# %%
#7 categories total for see_relatives
sns.swarmplot(data=data, x='income', y ='see_relatives' , order =['Never', 'Once a year', 'Sev times a year', 'Once a month', 'Sev time a mnth', 'Sev times a week', 'Almost daily'])                                                                  
sns.plt.title('Is income & time spent with family/relatives correlated?')
sns.plt.show()

sns.swarmplot(data=data, x='see_relatives', y ='income' , order =['Never', 'Once a year', 'Sev times a year', 'Once a month', 'Sev time a mnth', 'Sev times a week', 'Almost daily'])                                                                  
sns.plt.title('Is income & time spent with family/relatives correlated?')
sns.plt.show()

sns.barplot(data=data, x='income', y ='see_relatives' , order =['Never', 'Once a year', 'Sev times a year', 'Once a month', 'Sev time a mnth', 'Sev times a week', 'Almost daily'])                                                                  
sns.plt.title('Is income & time spent with family/relatives correlated?')
sns.plt.show()

sns.barplot(data=data, x='see_relatives', y ='income' , order =['Never', 'Once a year', 'Sev times a year', 'Once a month', 'Sev time a mnth', 'Sev times a week', 'Almost daily'])                                                                  
sns.plt.title('Is income & time spent with family/relatives correlated?')
sns.plt.show()

sns.violinplot(data=data, x='income', y ='see_relatives' , order =['Never', 'Once a year', 'Sev times a year', 'Once a month', 'Sev time a mnth', 'Sev times a week', 'Almost daily'])                                                                  
sns.plt.title('Is income & time spent with family/relatives correlated?')
sns.plt.show()

sns.violinplot(data=data, x='see_relatives', y ='income' , order =['Never', 'Once a year', 'Sev times a year', 'Once a month', 'Sev time a mnth', 'Sev times a week', 'Almost daily'])                                                                  
sns.plt.title('Is income & time spent with family/relatives correlated?')
sns.plt.show()

# %%
#7 categories total for see_friends
sns.swarmplot(data=data, x='income', y ='see_friends' , order =['Never', 'Once a year', 'Sev times a year', 'Once a month', 'Sev time a mnth', 'Sev times a week', 'Almost daily'])                                                                  
sns.plt.title('Is income & time spent with friends correlated?')
sns.plt.show()

sns.swarmplot(data=data, y='income', x ='see_friends' , order =['Never', 'Once a year', 'Sev times a year', 'Once a month', 'Sev time a mnth', 'Sev times a week', 'Almost daily'])                                                                  
sns.plt.title('Is income & time spent with friends correlated?')
sns.plt.show()

sns.barplot(data=data, x='income', y ='see_friends' , order =['Never', 'Once a year', 'Sev times a year', 'Once a month', 'Sev time a mnth', 'Sev times a week', 'Almost daily'])                                                                  
sns.plt.title('Is income & time spent with friends correlated?')
sns.plt.show()

sns.barplot(data=data, y='income', x ='see_friends' , order =['Never', 'Once a year', 'Sev times a year', 'Once a month', 'Sev time a mnth', 'Sev times a week', 'Almost daily'])                                                                  
sns.plt.title('Is income & time spent with friends correlated?')
sns.plt.show()

sns.violinplot(data=data, x='income', y ='see_friends' , order =['Never', 'Once a year', 'Sev times a year', 'Once a month', 'Sev time a mnth', 'Sev times a week', 'Almost daily'])                                                                  
sns.plt.title('Is income & time spent with friends correlated?')
sns.plt.show()

sns.violinplot(data=data, y='income', x ='see_friends' , order =['Never', 'Once a year', 'Sev times a year', 'Once a month', 'Sev time a mnth', 'Sev times a week', 'Almost daily'])                                                                  
sns.plt.title('Is income & time spent with friends correlated?')
sns.plt.show()

# %%
g = sns.lmplot(data=data, x= "internet_per_week", y= "income", hue = "see_relatives")
sns.plt.show()

g = sns.lmplot(data=data, x= "internet_per_week", y= "income", hue = "see_friends")
sns.plt.show()
