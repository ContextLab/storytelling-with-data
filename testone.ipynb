# %% [markdown]
# <a href="https://colab.research.google.com/github/apockert/storytelling-with-data/blob/master/testone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def addone(n):
  x = n + 1
  print(x)

addone(5)
# Out:
# 6
